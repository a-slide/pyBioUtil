# %% [markdown]
# # TEST pyBioUtil package
#
# ** This notebook contains tests for all function contained in pyBioUtil package **

# %%
# For ipythoninline ploting ploting
# %matplotlib inline

# Larger display 
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:75% !important; }</style>"))

# import all function from pyBioUtil
from pyBioUtil import *

# import helper pycl function
from pycl import *
# Out:
# <style>.container { width:75% !important; }</style>

# %% [markdown]
# ---
# # Fasta Tools

# %% [markdown]
# ## gencode_fasta_info

# %%
help(gencode_fasta_info)
# Out:
# Help on function gencode_fasta_info in module pyBioUtil:
#
# gencode_fasta_info(gencode_fasta, gencode_info='gencode_info.tsv')
#     Parse the header lines of a gencode transcript fasta file and generate a simple tabulated file containing
#     the information for each transcript
#     @param gencode_fasta Input file gziped or not, containing the gencode fasta sequences of transcripts
#     @param gencode_info Output file, simple tsv file with the transcript information [DEFAULT:gencode_info.tsv]

# %%
infile = "./test_data/gencode.transcript_sample.fa.gz"
outfile = "./test_data/gencode.transcript_sample.tsv"

gencode_fasta_info(infile, outfile)
head(outfile, 5)
# Out:
# Found 5000 Sequences
# GENCODE_transcript_id	GENCODE_gene_id	HAVANA_gene_id	HAVANA_transcript_id	transcript_name	gene_name	length	RNA_type
# ENST00000473358.1	ENSG00000243485.3	OTTHUMG00000000959.2	OTTHUMT00000002840.1	RP11-34P13.3-001	RP11-34P13.3	712
# ENST00000469289.1	ENSG00000243485.3	OTTHUMG00000000959.2	OTTHUMT00000002841.2	RP11-34P13.3-002	RP11-34P13.3	535
# ENST00000417324.1	ENSG00000237613.2	OTTHUMG00000000960.1	OTTHUMT00000002842.1	FAM138A-001	FAM138A	1187
# ENST00000461467.1	ENSG00000237613.2	OTTHUMG00000000960.1	OTTHUMT00000002843.1	FAM138A-002	FAM138A	590

# %% [markdown]
# ## gencode_fasta_clean

# %%
help(gencode_fasta_clean)
# Out:
# Help on function gencode_fasta_clean in module pyBioUtil:
#
# gencode_fasta_clean(gencode_fasta, clean_fasta='gencode_clean.fa.gz')
#     Parse the header lines of a gencode transcript fasta file and rewrite a file with clean header fields containing only the sequence ID
#     If you want to keep a track of the additional information you can use gencode_fasta_info beforehand
#     @param gencode_fasta Input file gziped or not, containing the gencode fasta sequences of transcripts
#     @param gencode_info Output file, fasta file whith clean sequence header field [DEFAULT:gencode_clean.fa.gz]

# %%
infile = "./test_data/gencode.transcript_sample.fa.gz"
outfile = "./test_data/gencode.transcript_sample_clean.fa.gz"

gencode_fasta_clean(infile, outfile)
head(outfile, 4)
# Out:
# Found 5000 Sequences
# >ENST00000473358.1
# ...
# >ENST00000469289.1
# ...

# %% [markdown]
# # fastqc_summary

# %%
help(fastqc_summary)
# Out:
# Help on function fastqc_summary in module pyBioUtil:
#
# fastqc_summary(fastqc_res_dir, table_if=['pass', 'warn', 'fail'], plot_if=['pass', 'warn', 'fail'], max_table_row=10)
#     Summarize and display fastqc results in IPYTHON/JUPYTER. Don't try to use in another interface or in terminal
#     Requires PANDAS third party python package to work. Works directly from the zipped results obtained by FastQC v0.11.5+
#     @param fastqc_res_dir Directory containing the zipped folders obtained with fastQC
#     @param table_if Output the tables for each individual section if in the following list ["pass", "warn", "fail"] [DEFAULT ALL]
#     @param plot_if Output the plot for each individual section if in the following list ["pass", "warn", "fail"] [DEFAULT ALL]
#     @param max_table_row  Maximal number of row for the tables [DEFAULT 10]

# %%
fastqc_summary("./test_data/", plot_if=["fail"], table_if=["pass", "warn", "fail"], max_table_row=5)
# Out:
# <hr></hr>
# <font size="4"><b>26IIR_1_fastqc.zip</b></font>
# <font size="3"><b>Basic Statistics : pass</b></font>
# <font size=2><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Filename</th>
#       <td>26IIR_1.fastq.gz</td>
#     </tr>
#     <tr>
#       <th>File type</th>
#       <td>Conventional base calls</td>
#     </tr>
#     <tr>
#       <th>Encoding</th>
#       <td>Sanger / Illumina 1.9</td>
#     </tr>
#     <tr>
#       <th>Total Sequences</th>
#       <td>65171330</td>
#     </tr>
#     <tr>
#       <th>Sequences flagged as poor quality</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table></font>
# <font size="3"><b>Per base sequence quality : pass</b></font>
# <font size="3"><b>Per tile sequence quality : warn</b></font>
# <font size="3"><b>Per sequence quality scores : pass</b></font>
# ...

# %%
from IPython.core.display import Image, display, HTML
display(Image("./test_data/32IIR_1_fastqc/Images/adapter_content.png"), Image("./test_data/32IIR_1_fastqc/Images/duplication_levels.png"))
